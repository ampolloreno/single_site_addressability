# %%
using SpecialFunctions
using QuantumOptics

function fidelity(ρ, σ)
    tr(sqrt(sqrt(ρ) * σ * sqrt(ρ)))^(1/2)
end

function R(n::Int64, m::Int64, ρ::Float64)
    if (n - m) % 2 != 0
        0
    else
        function summand(k)
            n = big(n)
            k = big(k)
            (-1)^k * factorial(n-k)/(factorial(k)*factorial(Int((n+m)/2) - k)*factorial(Int((n-m)/2) - k))*(ρ)^(n-2*k)
        end
        mapreduce(summand, +, Array(range(0, stop=Int((n-m)/2), step=1)))
    end
end

function sample_across_unit_disk(f, discretization)
    x = y = Array(range(-1, 1, length=discretization))
    z = Array{typeof(f(0.,0.))}(UndefInitializer(), length(x), length(y))
    for (i, xx) in enumerate(x)
        for (j, yy) in enumerate(y)
            if xx^2 + yy^2 > 1
                if typeof(f(0.,0.)) == Tuple{Float64,Float64}
                    z[i, j] = (0.,0.)
                else
                    z[i, j] = 0.
                end
            else
                ρ = sqrt(xx^2 + yy^2)
                ϕ = atan(yy, xx)
                res = f(ρ, ϕ)
                z[i, j] = res
            end
        end
    end
    x, y, z
end

function unpack_zernike(zernike_coefficients_even, zernike_coefficients_odd, ρ, ω, t)
    """Each Zernike array is of arbitrary length, but they are ordered by order. The first is Z00 to Zn0 where
    n is the number of 0th order zernike polynomials being considered."""
    Pevens = []
    eventuples = []
    for (n, zeven) in enumerate(zernike_coefficients_even)
        neven = n - 1
        push!(Pevens, [zeven[i] * R(neven, i-1, ρ) for i in Array(range(1, length(zeven), step=1))])
    end
    for i in range(1, length(Pevens), step=1)
        rotationeven = - (i - 1) * ω * t
        total = 0
        for peven in Pevens
            if length(peven) >= i
                total += peven[i]
            end
        end    
        push!(eventuples, (i - 1, total, rotationeven))
    end

    Podds = []
    oddtuples = []
    for (n, zodd) in enumerate(zernike_coefficients_odd)
        nodd = n - 1
        push!(Podds, [zodd[i] * R(nodd, i-1, ρ) for i in Array(range(1, length(zodd), step=1))])
    end
    for i in range(1, length(Podds), step=1)
        rotationodd = - (i - 1) * ω * t
        total = 0
        for podd in Podds
            if length(podd) >= i
                total += podd[i]
            end
        end    
        push!(oddtuples, (i - 1, total, rotationodd))
    end
    eventuples, oddtuples
end

function infidelity_across_disk(F1, F2)
    function infidelity_polar(ρ, ϕ)
        ψ1 = F1(ρ, ϕ).data
        ψ2 = F2(ρ, ϕ).data
        1 - real(fidelity(ψ1, ψ2))
    end
end

function H_odf(ρ, ϕ, t, zernike_coefficients_even, zernike_coefficients_odd, U, ψ, μ, ω)
    eventuples, oddtuples = unpack_zernike(zernike_coefficients_even, zernike_coefficients_odd, ρ, ω, t)
    eventerm = oddterm = 0
    if length(eventuples) > 0
        eventerm = mapreduce(x->x[2]*cos(x[1]*ϕ + x[3]), +, eventuples)
    end
    if length(oddtuples) > 0
        oddterm = mapreduce(x->x[2]*sin(x[1]*ϕ + x[3]), +, oddtuples)
    end
    U * cos(-μ*t + ψ + eventerm + oddterm) 
end

toarray(s::Union{Set, Array}) = [toarray.(s)...]
toarray(v::Number) = v
# Out:
# toarray (generic function with 2 methods)

# %%
max_order = 8
discretization = 50
zernike_samples = []
ordering = []
for n in range(0, max_order, step=1)
    for m in range(0, n, step=1)
        if (n-m)%2 == 0
            Zeven(ρ, ϕ) = R(n, m, ρ) * cos(m * ϕ)
            push!(zernike_samples, sample_across_unit_disk(Zeven, discretization)[3][:])
            push!(ordering, (n, m))
            if m !=0
                Zodd(ρ, ϕ) = R(n, m, ρ) * sin(m * ϕ)
                push!(zernike_samples, sample_across_unit_disk(Zodd, discretization)[3][:])
                push!(ordering, (n, -m))
            end
        end
    end
end

# %%
Z = reduce(hcat, zernike_samples);

# %%
σ = .5
amp = .01
function gaussian(σ)
    function func(ρ, ϕ)
        amp * exp(-ρ^2/σ^2)
    end
end
xx, yy, zz = sample_across_unit_disk(gaussian(σ), discretization)
# cells = 0
# for (i, x) in enumerate(xx)
#     for (j, y) in enumerate(yy)
#         if x^2 + y^2 <= 1
#             cells += 1
#         end
#     end
# end
# total = sum(zz)
# for (i, x) in enumerate(xx)
#     for (j, y) in enumerate(yy)
#         if x^2 + y^2 <= 1
#             zz[i, j] -= total/cells
#         end
#     end
# end
G = zz[:];

# %%
function least_squares_solution(mat, y)
    inv(transpose(mat) * mat)*transpose(mat) * y
end
# Out:
# least_squares_solution (generic function with 1 method)

# %%
coefficients = least_squares_solution(Z, G)
# Out:
# 45-element Array{BigFloat,1}:
#   0.002454545063805591781533863446370269026045248295077165595673648989562677336321538
#   3.703542790462827625421359576766486892688393787588550697992448733164733239596739e-22
#   3.380915824762601393433663787536205314581983708954900272896032595161635337064911e-80
#  -0.003955066341557543776013936575604578824710142256296604675525009678759973046101484
#  -1.306277640410753828038559426823739433324342856785004773460346210414156433382553e-21
#  -4.118046071574423134511161738777351174886703664987698261749126181682868863660062e-83
#   3.779006264332230722684215623907573025806475324595331937225638336064979826627197e-22
#  -8.310216972437185885443524388852694670921367995945175092209736634636029366866006e-80
#   1.210780302205386433567158290263880484682439856667111267921456923815165572988159e-21
#  -3.533283529410855049410576771870967308052791744559445108580750263883901485020333e-81
#   0.002382508416495657956967702032114003538852706390560699462339419964666025646059048
#  -1.557122280217246113088147558595521994662575599884245731577958907512699866338648e-21
#  -4.303358144795272175564164017022331977756605329912144683527836859858597962524765e-81
#   ⋮
#   4.104044714931070095853823788865508180892088872526740087659179152665147109523618e-80
#   1.305854039368501867653165461954998844083265130907712243643759584682755915535482e-21
#  -1.324569518921913201215515173277735005402308233843293145891606436338294769996259e-80
#   0.0002492085504337524659784815035108800478573352453256956393205280323656763057618607
#  -2.775892896389173569836359156120365222326119586030036869630652396991703435113159e-21
#   2.528480287946695804589853307609293621380436050302446732713963475553281482287278e-81
#   3.808493019989272006674162164002647107205848343278191595871924697391910288021332e-06
#   4.249823545864804674815518914418226412483078182267304606125098219496720667297184e-81
#  -5.273366733553393554072996771739747764492758354793787334388832616137883711919766e-21
#   1.037747610036754629896812758171892496071449323576899961960779797784082953642336e-81
#   7.234054808636129935653788401032515416150467059246956412979737533317527282712885e-06
#  -8.236092143148846269022323477554702349773407329975396523498252363365737727320125e-83

# %%
reconstruction = zeros(discretization*discretization)
for (i, zernike_sample) in enumerate(zernike_samples)
    reconstruction += coefficients[i] * zernike_sample
end

# %%
using Plots
plot(heatmap(xx, yy, reshape(reconstruction, (discretization, discretization))), aspectratio = true)

# %%
center = reshape(reconstruction, (discretization, discretization))[Int(discretization/2), Int(discretization/2)]
# Out:
# 0.009905225406671843612482861834577896145074113491042939573430556504221154934319227

# %%
lookup = Dict(zip(ordering, coefficients))
# Out:
# Dict{Any,BigFloat} with 45 entries:
#   (0, 0)  => 0.00245455
#   (4, 4)  => 2.73564e-06
#   (7, -1) => -8.63307e-80
#   (6, -2) => -3.21208e-82
#   (6, -4) => -9.88331e-83
#   (3, 1)  => 3.77901e-22
#   (4, 0)  => 0.00238251
#   (7, -5) => 4.10404e-80
#   (8, 4)  => 3.80849e-06
#   (8, 0)  => 0.000249209
#   (1, -1) => 3.38092e-80
#   (5, 1)  => 5.6776e-22
#   (4, -4) => 1.84488e-81
#   (7, -3) => -2.8431e-80
#   (3, -3) => -3.53328e-81
#   (8, 2)  => -2.77589e-21
#   (8, -6) => 1.03775e-81
#   (5, -1) => -1.09524e-79
#   (4, -2) => -4.30336e-81
#   (1, 1)  => 3.70354e-22
#   (7, 7)  => 1.30585e-21
#   (8, -4) => 4.24982e-81
#   (3, -1) => -8.31022e-80
#   (6, -6) => 7.5772e-82
#   (5, -3) => -2.27646e-80
#   ⋮       => ⋮

# %%
# For now, we assume the signal is zero mean. Then we can ignore the DC component.

# %%
zernike_even_coefficients = []
zernike_odd_coefficients = []
curr_even = []
curr_odd = []
for n in range(0, max_order, step=1)
    for m in range(0, n, step=1)
        if (n-m)%2 != 0
            push!(curr_even, 0)
            push!(curr_odd, 0)
        else
            if m == 0
                push!(curr_even, lookup[(n, m)])
                push!(curr_odd, lookup[(n, -m)])
            else
                push!(curr_even, lookup[(n, m)])
                push!(curr_odd, lookup[(n, -m)])
            end
        end
    end
    push!(zernike_even_coefficients, curr_even)
    push!(zernike_odd_coefficients, curr_odd)
    curr_even = []
    curr_odd = []
end

# %%
zernike_even_coefficients
# Out:
# 9-element Array{Any,1}:
#  Any[0.002454545063805591781533863446370269026045248295077165595673648989562677336321538]
#  Any[0, 3.703542790462827625421359576766486892688393787588550697992448733164733239596739e-22]
#  Any[-0.003955066341557543776013936575604578824710142256296604675525009678759973046101484, 0, -1.306277640410753828038559426823739433324342856785004773460346210414156433382553e-21]
#  Any[0, 3.779006264332230722684215623907573025806475324595331937225638336064979826627197e-22, 0, 1.210780302205386433567158290263880484682439856667111267921456923815165572988159e-21]
#  Any[0.002382508416495657956967702032114003538852706390560699462339419964666025646059048, 0, -1.557122280217246113088147558595521994662575599884245731577958907512699866338648e-21, 0, 2.735642786669430406280714854504426310793214872217360877821424640727337454698979e-06]
#  Any[0, 5.677599993509113403890189651334357533989819338732114935437092442597975808535914e-22, 0, 7.658808020004696133489666383484200933140221429992462300704359864661299096832462e-22, 0, -1.092147704819099220526939212775795630083826070532492443018328087033284089767823e-21]
#  Any[-0.0008954521233122686484119365975844567693416579542466971081029040238133460742309961, 0, -2.271882800148886125737101961024576588784353085127386552496210261138817184445354e-21, 0, 3.453394023271390717221998640047162213602534150895670140956342654026469873170712e-06, 0, -3.165595868540594007878003468633878244879540521487778082194471105799223057794306e-21]
#  Any[0, 3.765338276213687401035331444425878662801922530133548366220023328047745971110872e-22, 0, 1.236189744519183043504827235128379003036768972735986373001579229272224424089709e-21, 0, -3.243758565145357983381195859370698331168793342147331978981025219189335611891215e-22, 0, 1.305854039368501867653165461954998844083265130907712243643759584682755915535482e-21]
#  Any[0.0002492085504337524659784815035108800478573352453256956393205280323656763057618607, 0, -2.775892896389173569836359156120365222326119586030036869630652396991703435113159e-21, 0, 3.808493019989272006674162164002647107205848343278191595871924697391910288021332e-06, 0, -5.273366733553393554072996771739747764492758354793787334388832616137883711919766e-21, 0, 7.234054808636129935653788401032515416150467059246956412979737533317527282712885e-06]

# %%
function sequential_exact_evolution_evaluator_factory(ψ0, T, zernikeeven, zernikeodd, U, θ, ω, b)
    """Apply all the zernike coefficients given, in order, for time T each."""
    orders = range(0, 0, step=1)# max(length(zernikeeven), length(zernikeodd)) - 1, step=1)
    function evaluator(ρ, ϕ)
        ψ = ψ0
        for order in orders
            μ = order * ω
            H(t, _) = H_odf(ρ, ϕ, t, zernikeeven, zernikeodd, U, θ, μ, ω)*sigmaz(b), [sigmam(b)], [dagger(sigmam(b))]
            _, ψ = timeevolution.master_dynamic(T, ψ, H; rates=[Γ])
            ψ = last(ψ)
        end
        ψ
    end
end

function gaussian_spin_profile(ρ, ϕ)
    ψ0 = 1/sqrt(2) * (spindown(b) + spinup(b))
    H(t, _) = exp(-ρ^2/σ^2) * sigmaz(b), [sigmam(b)], [dagger(sigmam(b))]
    evolution_time = π/2
    step_size = evolution_time/1
    T = [0.0:step_size:evolution_time;];
    _, ψ = timeevolution.master_dynamic(T, ψ0, H; rates=[Γ])
    last(ψ)
end
# Out:
# gaussian_spin_profile (generic function with 1 method)

# %%
Γ = 1/62
ω = 2*π*180E3
U = 2*π*10E5 # We had to increase this, for faster gates.
θ = -π/2;

# %%
evolution_time
# Out:
# 2.846309428632200815170724367142103984845789390259944837876788077257236168467212e-05

# %%
b = SpinBasis(1//2)
ψ0 = 1/sqrt(2) * (spindown(b) + spinup(b))
evolution_time =  π / (2 * U * center)
step_size = evolution_time/1
T = [0.0:step_size:evolution_time;];
sequential_exact_evolution = sequential_exact_evolution_evaluator_factory(ψ0, T, zernike_even_coefficients, zernike_odd_coefficients, U, θ, ω, b)
# Out:
# (::var"#evaluator#257"{Ket{SpinBasis{1//2,Int64},Array{Complex{Float64},1}},Array{BigFloat,1},Array{Any,1},Array{Any,1},Float64,Float64,Float64,SpinBasis{1//2,Int64},StepRange{Int64,Int64}}) (generic function with 1 method)

# %%
plotting_discretization = 10
plot(heatmap(sample_across_unit_disk(infidelity_across_disk(gaussian_spin_profile, sequential_exact_evolution), plotting_discretization)), aspectratio = true)
# Out:
# InterruptException:
#
# Stacktrace:
#  [1] Array at ./boot.jl:406 [inlined]
#  [2] Array at ./boot.jl:415 [inlined]
#  [3] similar at ./abstractarray.jl:675 [inlined]
#  [4] similar at ./abstractarray.jl:674 [inlined]
#  [5] _array_for(::Type{Int64}, ::Array{Int64,1}, ::Base.HasShape{1}) at ./array.jl:678
#  [6] collect(::Base.Generator{Array{Int64,1},var"#231#233"{Float64,Array{Any,1},Int64}}) at ./array.jl:691
#  [7] unpack_zernike(::Array{Any,1}, ::Array{Any,1}, ::Float64, ::Float64, ::BigFloat) at ./In[483]:50
#  [8] H_odf(::Float64, ::Float64, ::BigFloat, ::Array{Any,1}, ::Array{Any,1}, ::Float64, ::Float64, ::Float64, ::Float64) at ./In[483]:91
#  [9] (::var"#H#244"{Float64,Float64,Float64,Array{Any,1},Array{Any,1},Float64,Float64,Float64,SpinBasis{1//2,Int64}})(::BigFloat, ::Operator{SpinBasis{1//2,Int64},SpinBasis{1//2,Int64},Array{Complex{Float64},2}}) at ./In[497]:8
#  [10] dmaster_h_dynamic(::BigFloat, ::Operator{SpinBasis{1//2,Int64},SpinBasis{1//2,Int64},Array{Complex{Float64},2}}, ::var"#H#244"{Float64,Float64,Float64,Array{Any,1},Array{Any,1},Float64,Float64,Float64,SpinBasis{1//2,Int64}}, ::Array{Float64,1}, ::Operator{SpinBasis{1//2,Int64},SpinBasis{1//2,Int64},Array{Complex{Float64},2}}, ::Operator{SpinBasis{1//2,Int64},SpinBasis{1//2,Int64},Array{Complex{Float64},2}}) at /home/ampolloreno/.julia/packages/QuantumOptics/MmggF/src/master.jl:288
#  [11] dmaster_ at /home/ampolloreno/.julia/packages/QuantumOptics/MmggF/src/master.jl:160 [inlined]
#  [12] df_ at /home/ampolloreno/.julia/packages/QuantumOptics/MmggF/src/timeevolution_base.jl:23 [inlined]
#  [13] ODEFunction at /home/ampolloreno/.julia/packages/DiffEqBase/m5bAm/src/diffeqfunction.jl:248 [inlined]
#  [14] perform_step!(::OrdinaryDiffEq.ODEIntegrator{OrdinaryDiffEq.DP5,true,Array{Complex{Float64},2},Nothing,BigFloat,DiffEqBase.NullParameters,BigFloat,BigFloat,BigFloat,Array{Array{Complex{Float64},2},1},DiffEqBase.ODESolution{Complex{Float64},3,Array{Array{Complex{Float64},2},1},Nothing,Nothing,Array{BigFloat,1},Array{Array{Array{Complex{Float64},2},1},1},DiffEqBase.ODEProblem{Array{Complex{Float64},2},Tuple{BigFloat,BigFloat},true,DiffEqBase.NullParameters,DiffEqBase.ODEFunction{true,QuantumOptics.timeevolution.var"#df_#3"{QuantumOptics.timeevolution.var"#dmaster_#18"{Operator{SpinBasis{1//2,Int64},SpinBasis{1//2,Int64},Array{Complex{Float64},2}},Array{Float64,1},var"#H#244"{Float64,Float64,Float64,Array{Any,1},Array{Any,1},Float64,Float64,Float64,SpinBasis{1//2,Int64}},Operator{SpinBasis{1//2,Int64},SpinBasis{1//2,Int64},Array{Complex{Float64},2}}},Operator{SpinBasis{1//2,Int64},SpinBasis{1//2,Int64},Array{Complex{Float64},2}},Operator{SpinBasis{1//2,Int64},SpinBasis{1//2,Int64},Array{Complex{Float64},2}}},LinearAlgebra.UniformScaling{Bool},Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing},Base.Iterators.Pairs{Union{},Union{},Tuple{},NamedTuple{(),Tuple{}}},DiffEqBase.StandardODEProblem},OrdinaryDiffEq.DP5,OrdinaryDiffEq.InterpolationData{DiffEqBase.ODEFunction{true,QuantumOptics.timeevolution.var"#df_#3"{QuantumOptics.timeevolution.var"#dmaster_#18"{Operator{SpinBasis{1//2,Int64},SpinBasis{1//2,Int64},Array{Complex{Float64},2}},Array{Float64,1},var"#H#244"{Float64,Float64,Float64,Array{Any,1},Array{Any,1},Float64,Float64,Float64,SpinBasis{1//2,Int64}},Operator{SpinBasis{1//2,Int64},SpinBasis{1//2,Int64},Array{Complex{Float64},2}}},Operator{SpinBasis{1//2,Int64},SpinBasis{1//2,Int64},Array{Complex{Float64},2}},Operator{SpinBasis{1//2,Int64},SpinBasis{1//2,Int64},Array{Complex{Float64},2}}},LinearAlgebra.UniformScaling{Bool},Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing},Array{Array{Complex{Float64},2},1},Array{BigFloat,1},Array{Array{Array{Complex{Float64},2},1},1},OrdinaryDiffEq.DP5Cache{Array{Complex{Float64},2},Array{Complex{Float64},2},Array{Complex{Float64},2},OrdinaryDiffEq.DP5ConstantCache{Complex{Float64},BigFloat}}},DiffEqBase.DEStats},DiffEqBase.ODEFunction{true,QuantumOptics.timeevolution.var"#df_#3"{QuantumOptics.timeevolution.var"#dmaster_#18"{Operator{SpinBasis{1//2,Int64},SpinBasis{1//2,Int64},Array{Complex{Float64},2}},Array{Float64,1},var"#H#244"{Float64,Float64,Float64,Array{Any,1},Array{Any,1},Float64,Float64,Float64,SpinBasis{1//2,Int64}},Operator{SpinBasis{1//2,Int64},SpinBasis{1//2,Int64},Array{Complex{Float64},2}}},Operator{SpinBasis{1//2,Int64},SpinBasis{1//2,Int64},Array{Complex{Float64},2}},Operator{SpinBasis{1//2,Int64},SpinBasis{1//2,Int64},Array{Complex{Float64},2}}},LinearAlgebra.UniformScaling{Bool},Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing},OrdinaryDiffEq.DP5Cache{Array{Complex{Float64},2},Array{Complex{Float64},2},Array{Complex{Float64},2},OrdinaryDiffEq.DP5ConstantCache{Complex{Float64},BigFloat}},OrdinaryDiffEq.DEOptions{Float64,Float64,BigFloat,BigFloat,typeof(DiffEqBase.ODE_DEFAULT_NORM),typeof(LinearAlgebra.opnorm),DiffEqBase.CallbackSet{Tuple{},Tuple{DiffEqBase.DiscreteCallback{DiffEqCallbacks.var"#30#31",DiffEqCallbacks.SavingAffect{QuantumOptics.timeevolution.var"#fout_#4"{Operator{SpinBasis{1//2,Int64},SpinBasis{1//2,Int64},Array{Complex{Float64},2}},QuantumOptics.timeevolution.var"#fout#7"{Operator{SpinBasis{1//2,Int64},SpinBasis{1//2,Int64},Array{Complex{Float64},2}}}},BigFloat,Operator{SpinBasis{1//2,Int64},SpinBasis{1//2,Int64},Array{Complex{Float64},2}},DataStructures.BinaryHeap{BigFloat,Base.Order.ForwardOrdering},Array{BigFloat,1}},typeof(DiffEqCallbacks.saving_initialize)}}},typeof(DiffEqBase.ODE_DEFAULT_ISOUTOFDOMAIN),typeof(DiffEqBase.ODE_DEFAULT_PROG_MESSAGE),typeof(DiffEqBase.ODE_DEFAULT_UNSTABLE_CHECK),DataStructures.Bi ...
#  [15] perform_step! at /home/ampolloreno/.julia/packages/OrdinaryDiffEq/yBRRy/src/perform_step/low_order_rk_perform_step.jl:775 [inlined]
#  [16] solve!(::OrdinaryDiffEq.ODEIntegrator{OrdinaryDiffEq.DP5,true,Array{Complex{Float64},2},Nothing,BigFloat,DiffEqBase.NullParameters,BigFloat,BigFloat,BigFloat,Array{Array{Complex{Float64},2},1},DiffEqBase.ODESolution{Complex{Float64},3,Array{Array{Complex{Float64},2},1},Nothing,Nothing,Array{BigFloat,1},Array{Array{Array{Complex{Float64},2},1},1},DiffEqBase.ODEProblem{Array{Complex{Float64},2},Tuple{BigFloat,BigFloat},true,DiffEqBase.NullParameters,DiffEqBase.ODEFunction{true,QuantumOptics.timeevolution.var"#df_#3"{QuantumOptics.timeevolution.var"#dmaster_#18"{Operator{SpinBasis{1//2,Int64},SpinBasis{1//2,Int64},Array{Complex{Float64},2}},Array{Float64,1},var"#H#244"{Float64,Float64,Float64,Array{Any,1},Array{Any,1},Float64,Float64,Float64,SpinBasis{1//2,Int64}},Operator{SpinBasis{1//2,Int64},SpinBasis{1//2,Int64},Array{Complex{Float64},2}}},Operator{SpinBasis{1//2,Int64},SpinBasis{1//2,Int64},Array{Complex{Float64},2}},Operator{SpinBasis{1//2,Int64},SpinBasis{1//2,Int64},Array{Complex{Float64},2}}},LinearAlgebra.UniformScaling{Bool},Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing},Base.Iterators.Pairs{Union{},Union{},Tuple{},NamedTuple{(),Tuple{}}},DiffEqBase.StandardODEProblem},OrdinaryDiffEq.DP5,OrdinaryDiffEq.InterpolationData{DiffEqBase.ODEFunction{true,QuantumOptics.timeevolution.var"#df_#3"{QuantumOptics.timeevolution.var"#dmaster_#18"{Operator{SpinBasis{1//2,Int64},SpinBasis{1//2,Int64},Array{Complex{Float64},2}},Array{Float64,1},var"#H#244"{Float64,Float64,Float64,Array{Any,1},Array{Any,1},Float64,Float64,Float64,SpinBasis{1//2,Int64}},Operator{SpinBasis{1//2,Int64},SpinBasis{1//2,Int64},Array{Complex{Float64},2}}},Operator{SpinBasis{1//2,Int64},SpinBasis{1//2,Int64},Array{Complex{Float64},2}},Operator{SpinBasis{1//2,Int64},SpinBasis{1//2,Int64},Array{Complex{Float64},2}}},LinearAlgebra.UniformScaling{Bool},Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing},Array{Array{Complex{Float64},2},1},Array{BigFloat,1},Array{Array{Array{Complex{Float64},2},1},1},OrdinaryDiffEq.DP5Cache{Array{Complex{Float64},2},Array{Complex{Float64},2},Array{Complex{Float64},2},OrdinaryDiffEq.DP5ConstantCache{Complex{Float64},BigFloat}}},DiffEqBase.DEStats},DiffEqBase.ODEFunction{true,QuantumOptics.timeevolution.var"#df_#3"{QuantumOptics.timeevolution.var"#dmaster_#18"{Operator{SpinBasis{1//2,Int64},SpinBasis{1//2,Int64},Array{Complex{Float64},2}},Array{Float64,1},var"#H#244"{Float64,Float64,Float64,Array{Any,1},Array{Any,1},Float64,Float64,Float64,SpinBasis{1//2,Int64}},Operator{SpinBasis{1//2,Int64},SpinBasis{1//2,Int64},Array{Complex{Float64},2}}},Operator{SpinBasis{1//2,Int64},SpinBasis{1//2,Int64},Array{Complex{Float64},2}},Operator{SpinBasis{1//2,Int64},SpinBasis{1//2,Int64},Array{Complex{Float64},2}}},LinearAlgebra.UniformScaling{Bool},Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing},OrdinaryDiffEq.DP5Cache{Array{Complex{Float64},2},Array{Complex{Float64},2},Array{Complex{Float64},2},OrdinaryDiffEq.DP5ConstantCache{Complex{Float64},BigFloat}},OrdinaryDiffEq.DEOptions{Float64,Float64,BigFloat,BigFloat,typeof(DiffEqBase.ODE_DEFAULT_NORM),typeof(LinearAlgebra.opnorm),DiffEqBase.CallbackSet{Tuple{},Tuple{DiffEqBase.DiscreteCallback{DiffEqCallbacks.var"#30#31",DiffEqCallbacks.SavingAffect{QuantumOptics.timeevolution.var"#fout_#4"{Operator{SpinBasis{1//2,Int64},SpinBasis{1//2,Int64},Array{Complex{Float64},2}},QuantumOptics.timeevolution.var"#fout#7"{Operator{SpinBasis{1//2,Int64},SpinBasis{1//2,Int64},Array{Complex{Float64},2}}}},BigFloat,Operator{SpinBasis{1//2,Int64},SpinBasis{1//2,Int64},Array{Complex{Float64},2}},DataStructures.BinaryHeap{BigFloat,Base.Order.ForwardOrdering},Array{BigFloat,1}},typeof(DiffEqCallbacks.saving_initialize)}}},typeof(DiffEqBase.ODE_DEFAULT_ISOUTOFDOMAIN),typeof(DiffEqBase.ODE_DEFAULT_PROG_MESSAGE),typeof(DiffEqBase.ODE_DEFAULT_UNSTABLE_CHECK),DataStructures.BinaryHea ...
#  [17] #__solve#391 at /home/ampolloreno/.julia/packages/OrdinaryDiffEq/yBRRy/src/solve.jl:5 [inlined]
#  [18] #solve_call#455 at /home/ampolloreno/.julia/packages/DiffEqBase/m5bAm/src/solve.jl:65 [inlined]
#  [19] solve_up(::DiffEqBase.ODEProblem{Array{Complex{Float64},2},Tuple{BigFloat,BigFloat},true,DiffEqBase.NullParameters,DiffEqBase.ODEFunction{true,QuantumOptics.timeevolution.var"#df_#3"{QuantumOptics.timeevolution.var"#dmaster_#18"{Operator{SpinBasis{1//2,Int64},SpinBasis{1//2,Int64},Array{Complex{Float64},2}},Array{Float64,1},var"#H#244"{Float64,Float64,Float64,Array{Any,1},Array{Any,1},Float64,Float64,Float64,SpinBasis{1//2,Int64}},Operator{SpinBasis{1//2,Int64},SpinBasis{1//2,Int64},Array{Complex{Float64},2}}},Operator{SpinBasis{1//2,Int64},SpinBasis{1//2,Int64},Array{Complex{Float64},2}},Operator{SpinBasis{1//2,Int64},SpinBasis{1//2,Int64},Array{Complex{Float64},2}}},LinearAlgebra.UniformScaling{Bool},Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing},Base.Iterators.Pairs{Union{},Union{},Tuple{},NamedTuple{(),Tuple{}}},DiffEqBase.StandardODEProblem}, ::Nothing, ::Array{Complex{Float64},2}, ::DiffEqBase.NullParameters, ::OrdinaryDiffEq.DP5; kwargs::Base.Iterators.Pairs{Symbol,Any,NTuple{6,Symbol},NamedTuple{(:reltol, :abstol, :save_everystep, :save_start, :save_end, :callback),Tuple{Float64,Float64,Bool,Bool,Bool,DiffEqBase.CallbackSet{Tuple{},Tuple{DiffEqBase.DiscreteCallback{DiffEqCallbacks.var"#30#31",DiffEqCallbacks.SavingAffect{QuantumOptics.timeevolution.var"#fout_#4"{Operator{SpinBasis{1//2,Int64},SpinBasis{1//2,Int64},Array{Complex{Float64},2}},QuantumOptics.timeevolution.var"#fout#7"{Operator{SpinBasis{1//2,Int64},SpinBasis{1//2,Int64},Array{Complex{Float64},2}}}},BigFloat,Operator{SpinBasis{1//2,Int64},SpinBasis{1//2,Int64},Array{Complex{Float64},2}},DataStructures.BinaryHeap{BigFloat,Base.Order.ForwardOrdering},Array{BigFloat,1}},typeof(DiffEqCallbacks.saving_initialize)}}}}}}) at /home/ampolloreno/.julia/packages/DiffEqBase/m5bAm/src/solve.jl:86
#  [20] #solve#456 at /home/ampolloreno/.julia/packages/DiffEqBase/m5bAm/src/solve.jl:74 [inlined]
#  [21] integrate(::Array{BigFloat,1}, ::QuantumOptics.timeevolution.var"#dmaster_#18"{Operator{SpinBasis{1//2,Int64},SpinBasis{1//2,Int64},Array{Complex{Float64},2}},Array{Float64,1},var"#H#244"{Float64,Float64,Float64,Array{Any,1},Array{Any,1},Float64,Float64,Float64,SpinBasis{1//2,Int64}},Operator{SpinBasis{1//2,Int64},SpinBasis{1//2,Int64},Array{Complex{Float64},2}}}, ::Array{Complex{Float64},2}, ::Operator{SpinBasis{1//2,Int64},SpinBasis{1//2,Int64},Array{Complex{Float64},2}}, ::Operator{SpinBasis{1//2,Int64},SpinBasis{1//2,Int64},Array{Complex{Float64},2}}, ::QuantumOptics.timeevolution.var"#fout#7"{Operator{SpinBasis{1//2,Int64},SpinBasis{1//2,Int64},Array{Complex{Float64},2}}}; alg::OrdinaryDiffEq.DP5, steady_state::Bool, tol::Float64, save_everystep::Bool, saveat::Array{BigFloat,1}, callback::Nothing, kwargs::Base.Iterators.Pairs{Union{},Union{},Tuple{},NamedTuple{(),Tuple{}}}) at /home/ampolloreno/.julia/packages/QuantumOptics/MmggF/src/timeevolution_base.jl:57
#  [22] integrate(::Array{BigFloat,1}, ::Function, ::Array{Complex{Float64},2}, ::Operator{SpinBasis{1//2,Int64},SpinBasis{1//2,Int64},Array{Complex{Float64},2}}, ::Operator{SpinBasis{1//2,Int64},SpinBasis{1//2,Int64},Array{Complex{Float64},2}}, ::Function) at /home/ampolloreno/.julia/packages/QuantumOptics/MmggF/src/timeevolution_base.jl:20
#  [23] #integrate#6 at /home/ampolloreno/.julia/packages/QuantumOptics/MmggF/src/timeevolution_base.jl:73 [inlined]
#  [24] integrate at /home/ampolloreno/.julia/packages/QuantumOptics/MmggF/src/timeevolution_base.jl:70 [inlined]
#  [25] #integrate_master#24 at /home/ampolloreno/.julia/packages/QuantumOptics/MmggF/src/master.jl:185 [inlined]
#  [26] integrate_master at /home/ampolloreno/.julia/packages/QuantumOptics/MmggF/src/master.jl:181 [inlined]
#  [27] #master_dynamic#17 at /home/ampolloreno/.julia/packages/QuantumOptics/MmggF/src/master.jl:161 [inlined]
#  [28] #master_dynamic#22 at /home/ampolloreno/.julia/packages/QuantumOptics/MmggF/src/master.jl:169 [inlined]
#  [29] (::var"#evaluator#243"{Ket{SpinBasis{1//2,Int64},Array{Complex{Float64},1}},Array{BigFloat,1},Array{Any,1},Array{Any,1},Float64,Float64,Float64,SpinBasis{1//2,Int64},StepRange{Int64,Int64}})(::Float64, ::Float64) at ./In[497]:9
#  [30] (::var"#infidelity_polar#235"{typeof(gaussian_spin_profile),var"#evaluator#243"{Ket{SpinBasis{1//2,Int64},Array{Complex{Float64},1}},Array{BigFloat,1},Array{Any,1},Array{Any,1},Float64,Float64,Float64,SpinBasis{1//2,Int64},StepRange{Int64,Int64}}})(::Float64, ::Float64) at ./In[483]:85
#  [31] sample_across_unit_disk(::var"#infidelity_polar#235"{typeof(gaussian_spin_profile),var"#evaluator#243"{Ket{SpinBasis{1//2,Int64},Array{Complex{Float64},1}},Array{BigFloat,1},Array{Any,1},Array{Any,1},Float64,Float64,Float64,SpinBasis{1//2,Int64},StepRange{Int64,Int64}}}, ::Int64) at ./In[483]:27
#  [32] top-level scope at In[504]:3
#  [33] include_string(::Function, ::Module, ::String, ::String) at ./loading.jl:1091

# %%
using Plots
max_ρ = 1
min_ρ = .0
ρs = range(min_ρ, max_ρ, step=max_ρ/20)
target = [Real.(expect(sigmax(b), gaussian_spin_profile(ρ, 0.))) for ρ in ρs]
ys = [Real.(expect(sigmax(b), sequential_exact_evolution(ρ, 0.))) for ρ in ρs];
plot(ρs, [ys, target])
