# %%
using SpecialFunctions
using QuantumOptics

function fidelity(ρ, σ)
    tr(sqrt(sqrt(ρ) * σ * sqrt(ρ)))^(1/2)
end

function R(n::Int64, m::Int64, ρ::Float64)
    if (n - m) % 2 != 0
        0
    else
        function summand(k)
            n = big(n)
            k = big(k)
            (-1)^k * factorial(n-k)/(factorial(k)*factorial(Int((n+m)/2) - k)*factorial(Int((n-m)/2) - k))*(ρ)^(n-2*k)
        end
        mapreduce(summand, +, Array(range(0, stop=Int((n-m)/2), step=1)))
    end
end

function sample_across_unit_disk(f, discretization)
    x = y = Array(range(-1, 1, length=discretization))
    z = Array{typeof(f(0.,0.))}(UndefInitializer(), length(x), length(y))
    for (i, xx) in enumerate(x)
        for (j, yy) in enumerate(y)
            if xx^2 + yy^2 > 1
                if typeof(f(0.,0.)) == Tuple{Float64,Float64}
                    z[i, j] = (0.,0.)
                else
                    z[i, j] = 0.
                end
            else
                ρ = sqrt(xx^2 + yy^2)
                ϕ = atan(yy, xx)
                res = f(ρ, ϕ)
                z[i, j] = res
            end
        end
    end
    x, y, z
end

function unpack_zernike(zernike_coefficients_even, zernike_coefficients_odd, ρ, ω, t)
    """Each Zernike array is of arbitrary length, but they are ordered by order. The first is Z00 to Zn0 where
    n is the number of 0th order zernike polynomials being considered."""
    Pevens = []
    eventuples = []
    for (n, zeven) in enumerate(zernike_coefficients_even)
        neven = n - 1
        push!(Pevens, [zeven[i] * R(neven, i-1, ρ) for i in Array(range(1, length(zeven), step=1))])
    end
    for i in range(1, length(Pevens), step=1)
        rotationeven = - (i - 1) * ω * t
        total = 0
        for peven in Pevens
            if length(peven) >= i
                total += peven[i]
            end
        end    
        push!(eventuples, (i - 1, total, rotationeven))
    end

    Podds = []
    oddtuples = []
    for (n, zodd) in enumerate(zernike_coefficients_odd)
        nodd = n - 1
        push!(Podds, [zodd[i] * R(nodd, i-1, ρ) for i in Array(range(1, length(zodd), step=1))])
    end
    for i in range(1, length(Podds), step=1)
        rotationodd = - (i - 1) * ω * t
        total = 0
        for podd in Podds
            if length(podd) >= i
                total += podd[i]
            end
        end    
        push!(oddtuples, (i - 1, total, rotationodd))
    end
    eventuples, oddtuples
end

function infidelity_across_disk(F1, F2)
    function infidelity_polar(ρ, ϕ)
        ψ1 = F1(ρ, ϕ).data
        ψ2 = F2(ρ, ϕ).data
        1 - real(fidelity(ψ1, ψ2))
    end
end

function H_odf(ρ, ϕ, t, zernike_coefficients_even, zernike_coefficients_odd, U, ψ, μ, ω)
    eventuples, oddtuples = unpack_zernike(zernike_coefficients_even, zernike_coefficients_odd, ρ, ω, t)
    eventerm = oddterm = 0
    if length(eventuples) > 0
        eventerm = mapreduce(x->x[2]*cos(x[1]*ϕ + x[3]), +, eventuples)
    end
    if length(oddtuples) > 0
        oddterm = mapreduce(x->x[2]*sin(x[1]*ϕ + x[3]), +, oddtuples)
    end
    U * cos(-μ*t + ψ + eventerm + oddterm) 
end

function least_squares_solution(mat, y)
    inv(transpose(mat) * mat)*transpose(mat) * y
end

toarray(s::Union{Set, Array}) = [toarray.(s)...]
toarray(v::Number) = v
# Out:
# ┌ Info: Precompiling QuantumOptics [6e0679c1-51ea-5a7c-ac74-d61b76210b0c]
# └ @ Base loading.jl:1278
# toarray (generic function with 2 methods)

# %%
time()
# Out:
# 1.602195077462926e9

# %%
max_order = 20
discretization = 100
zernike_samples = []
ordering = []
for n in range(0, max_order, step=1)
    for m in range(0, n, step=1)
        if (n-m)%2 == 0
            Zeven(ρ, ϕ) = R(n, m, ρ) * cos(m * ϕ)
            push!(zernike_samples, sample_across_unit_disk(Zeven, discretization)[3][:])
            push!(ordering, (n, m))
            if m !=0
                Zodd(ρ, ϕ) = R(n, m, ρ) * sin(m * ϕ)
                push!(zernike_samples, sample_across_unit_disk(Zodd, discretization)[3][:])
                push!(ordering, (n, -m))
            end
        end
    end
end
Z = reduce(hcat, zernike_samples);

# %%
σ1 = .1
σ2 = 1
amp = 1 # Used to make the small angle approximation work better.
function gaussian(σ1, σ2)
    function func(ρ, ϕ)
        x = ρ*cos(ϕ)
        y = ρ*sin(ϕ)
        amp * exp(-x^2/σ1^2 + -y^2/σ2^2)
    end
end
xx, yy, zz = sample_across_unit_disk(gaussian(σ1, σ2), discretization)
G = zz[:];

# %%
coefficients = least_squares_solution(Z, G)
# Out:
# 231-element Array{BigFloat,1}:
#   0.08504313016722482607742715654714324659424032484441359852818128589927245101606757
#  -5.496616568976501312120961812958936898423948702103648576284243366153455691921383e-18
#   5.485105589862841233628563078875790889711492907246334478305460101963767474591566e-78
#  -0.1197229896580479499390019100765764253904217948000592155309866516276659907697968
#  -0.1193317443853311646883388159718287295694141623526778325082358366714511191116121
#   3.297731294116798046116538320412902820849272294922148768008700246291641386018978e-80
#  -3.57992920090752104235102439728709505804412052919266738239794938357739367163477e-18
#  -1.090590377227197627558859985603883466347595505006022106055544584947437526900822e-78
#  -1.444243726543664178262247810741291607227227631117130462189016325741701589011436e-17
#   1.591476557004937862255721610214850244451415045185805821028614300677888232525522e-78
#   0.1170226318906687438938740945355895193687059935384675784050897629790012722736475
#   0.1869102270081420950414574021925297778599639831077618764780167283491037317165504
#   5.007544023034498531565572674353259028662231656625041086286937436926368538210636e-81
#   ⋮
#   0.07542422341881735210975026606556379327884635565687542657939037694887656227184252
#   5.798208868776787773391715728198510454240478760302679152542769663809479360033368e-81
#   0.06880848453919539242629208681190015461131942017616966500461393116720411361772587
#   1.454823316165812204960103219075262623063974670766854041910731297464923912153827e-79
#   0.06364547592663957070379666666973967972966711449132121101503821461006271292039947
#   2.445789922829481388048869179894644409788711040709493751618041021825089475504984e-79
#   0.05530708136757976836131012099087723354734115859158371723354483476472318096813298
#   2.39835003208494403353930059666392932425401621448883546764269108821210282619562e-80
#   0.05243318380021428026650423585553431086281255168601651563515666348656822048095467
#  -7.761693235703472723926637645247551494426459067768813683744753027235871234226485e-80
#   0.04411226063004275082087728545445763657061705431458318617127472819659924115071069
#  -7.023739379677336098222237461658650163886761771003018155239309615478301133858602e-80

# %%
reconstruction = zeros(discretization*discretization)
for (i, zernike_sample) in enumerate(zernike_samples)
    reconstruction += coefficients[i] * zernike_sample
end

# %%
using Plots
plot(heatmap(xx, yy, reshape(reconstruction, (discretization, discretization))), aspectratio = true, xlabel="x", ylabel="y", title="Reconstruction of a Gaussian using n <= 20")
# Out:
# ┌ Info: Precompiling Plots [91a5bcdd-55d7-5caf-9e0b-520d859cae80]
# └ @ Base loading.jl:1278

# %%
using Plots
diff = sample_across_unit_disk(gaussian(σ1,σ2), discretization)[3] - reshape(reconstruction, (discretization, discretization))
plot(heatmap(xx, yy, diff), aspectratio = true, xlabel="x", ylabel="y", title="Error in Reconstruction of a Gaussian using n <= 20")

# %%
plot(reshape(reconstruction, (discretization, discretization))[:,Int64(discretization/2)])

# %%
plot(reshape(reconstruction, (discretization, discretization))[Int64(discretization/2), :])

# %%
lookup = Dict(zip(ordering, coefficients));
zernike_even_coefficients = []
zernike_odd_coefficients = []
curr_even = []
curr_odd = []
for n in range(0, max_order, step=1)
    for m in range(0, n, step=1)
        if (n-m)%2 != 0
            push!(curr_even, 0)
            push!(curr_odd, 0)
        else
            if m == 0
                push!(curr_even, lookup[(n, m)]/2)
                push!(curr_odd, lookup[(n, -m)]/2)
            else
                push!(curr_even, lookup[(n, m)])
                push!(curr_odd, lookup[(n, -m)])
            end
        end
    end
    push!(zernike_even_coefficients, curr_even)
    push!(zernike_odd_coefficients, curr_odd)
    curr_even = []
    curr_odd = []
end

# %%
function sequential_exact_evolution_evaluator_factory(ψ0, T, zernikeeven, zernikeodd, U, θ, ω, b)
    """Apply all the zernike coefficients given, in order, for time T each."""
    orders = range(0, max(length(zernikeeven), length(zernikeodd)) - 1, step=1)
    function evaluator(ρ, ϕ)
        ψ = ψ0
        for order in orders
            print(order)
            μ = order * ω
            H(t, _) = H_odf(ρ, ϕ, t, zernikeeven, zernikeodd, U, θ, μ, ω)*sigmaz(b), [], []
            _, ψ = @skiptimechecks timeevolution.master_dynamic(T, ψ, H)
            ψ = last(ψ)
        end
        ψ
    end
end

function gaussian_spin_profile(ρ, ϕ)
    ψ0 = 1/sqrt(2) * (spindown(b) + spinup(b))
    H(t, _) = gaussian(σ1, σ2)(ρ, ϕ) * sigmaz(b), [], []
    evolution_time = π/2
    step_size = evolution_time/1
    T = [0.0:step_size:evolution_time;];
    _, ψ = timeevolution.master_dynamic(T, ψ0, H)
    last(ψ)
end
# Out:
# gaussian_spin_profile (generic function with 1 method)

# %%
Γ = 1/62
ω = 2*π*180E3
θ = -π/2;

# %%
b = SpinBasis(1//2)
ψ0 = 1/sqrt(2) * (spindown(b) + spinup(b))
evolution_time =  50E-6
U = π/(evolution_time)
step_size = evolution_time
T = [0.0:step_size:evolution_time;];
sequential_exact_evolution = sequential_exact_evolution_evaluator_factory(ψ0, T, zernike_even_coefficients, zernike_odd_coefficients, U, θ, ω, b)
# Out:
# (::var"#evaluator#21"{Ket{SpinBasis{1//2,Int64},Array{Complex{Float64},1}},Array{Float64,1},Array{Any,1},Array{Any,1},Float64,Float64,Float64,SpinBasis{1//2,Int64},StepRange{Int64,Int64}}) (generic function with 1 method)

# %%
spindown(b)
# Out:
# Ket(dim=2)
#   basis: Spin(1/2)
#  0.0 + 0.0im
#  1.0 + 0.0im

# %%
using Plots
max_ρ = 1
min_ρ = .0
ρs = range(min_ρ, max_ρ, step=max_ρ/10)
angle = 0
target = []
for ρ in ρs
    print(ρ)
    Real.(expect(sigmax(b), sequential_exact_evolution(ρ, angle)))
end
# Out:
# 0.0012345678910
# InterruptException:
#
# Stacktrace:
#  [1] _BigFloat at ./mpfr.jl:108 [inlined]
#  [2] BigFloat(; precision::Int64) at ./mpfr.jl:118
#  [3] BigFloat at ./mpfr.jl:112 [inlined]
#  [4] /(::BigFloat, ::Int64) at ./mpfr.jl:426
#  [5] /(::BigInt, ::Int64) at ./gmp.jl:540
#  [6] (::var"#summand#1"{Int64,Float64})(::Int64) at ./In[1]:15
#  [7] _mapreduce(::var"#summand#1"{Int64,Float64}, ::typeof(+), ::IndexLinear, ::Array{Int64,1}) at ./reduce.jl:408
#  [8] _mapreduce_dim(::Function, ::Function, ::NamedTuple{(),Tuple{}}, ::Array{Int64,1}, ::Colon) at ./reducedim.jl:318
#  [9] #mapreduce#620 at ./reducedim.jl:310 [inlined]
#  [10] mapreduce(::Function, ::Function, ::Array{Int64,1}) at ./reducedim.jl:310
#  [11] R(::Int64, ::Int64, ::Float64) at ./In[1]:17
#  [12] (::var"#2#4"{Float64,Array{Any,1},Int64})(::Int64) at ./array.jl:0
#  [13] iterate at ./generator.jl:47 [inlined]
#  [14] collect_to!(::Array{Real,1}, ::Base.Generator{Array{Int64,1},var"#2#4"{Float64,Array{Any,1},Int64}}, ::Int64, ::Int64) at ./array.jl:732
#  [15] collect_to!(::Array{BigFloat,1}, ::Base.Generator{Array{Int64,1},var"#2#4"{Float64,Array{Any,1},Int64}}, ::Int64, ::Int64) at ./array.jl:740
#  [16] collect_to_with_first!(::Array{BigFloat,1}, ::BigFloat, ::Base.Generator{Array{Int64,1},var"#2#4"{Float64,Array{Any,1},Int64}}, ::Int64) at ./array.jl:710
#  [17] collect(::Base.Generator{Array{Int64,1},var"#2#4"{Float64,Array{Any,1},Int64}}) at ./array.jl:691
#  [18] unpack_zernike(::Array{Any,1}, ::Array{Any,1}, ::Float64, ::Float64, ::Float64) at ./In[1]:50
#  [19] H_odf(::Float64, ::Int64, ::Float64, ::Array{Any,1}, ::Array{Any,1}, ::Float64, ::Float64, ::Float64, ::Float64) at ./In[1]:91
#  [20] (::var"#H#22"{Float64,Int64,Float64,Array{Any,1},Array{Any,1},Float64,Float64,Float64,SpinBasis{1//2,Int64}})(::Float64, ::Operator{SpinBasis{1//2,Int64},SpinBasis{1//2,Int64},Array{Complex{Float64},2}}) at ./In[25]:9
#  [21] dmaster_h_dynamic(::Float64, ::Operator{SpinBasis{1//2,Int64},SpinBasis{1//2,Int64},Array{Complex{Float64},2}}, ::var"#H#22"{Float64,Int64,Float64,Array{Any,1},Array{Any,1},Float64,Float64,Float64,SpinBasis{1//2,Int64}}, ::Nothing, ::Operator{SpinBasis{1//2,Int64},SpinBasis{1//2,Int64},Array{Complex{Float64},2}}, ::Operator{SpinBasis{1//2,Int64},SpinBasis{1//2,Int64},Array{Complex{Float64},2}}) at /home/ampolloreno/.julia/packages/QuantumOptics/MmggF/src/master.jl:288
#  [22] dmaster_ at /home/ampolloreno/.julia/packages/QuantumOptics/MmggF/src/master.jl:160 [inlined]
#  [23] df_ at /home/ampolloreno/.julia/packages/QuantumOptics/MmggF/src/timeevolution_base.jl:23 [inlined]
#  [24] ODEFunction at /home/ampolloreno/.julia/packages/DiffEqBase/gLFRA/src/diffeqfunction.jl:248 [inlined]
#  [25] perform_step!(::OrdinaryDiffEq.ODEIntegrator{OrdinaryDiffEq.DP5,true,Array{Complex{Float64},2},Nothing,Float64,DiffEqBase.NullParameters,Float64,Float64,Float64,Array{Array{Complex{Float64},2},1},DiffEqBase.ODESolution{Complex{Float64},3,Array{Array{Complex{Float64},2},1},Nothing,Nothing,Array{Float64,1},Array{Array{Array{Complex{Float64},2},1},1},DiffEqBase.ODEProblem{Array{Complex{Float64},2},Tuple{Float64,Float64},true,DiffEqBase.NullParameters,DiffEqBase.ODEFunction{true,QuantumOptics.timeevolution.var"#df_#3"{QuantumOptics.timeevolution.var"#dmaster_#18"{Operator{SpinBasis{1//2,Int64},SpinBasis{1//2,Int64},Array{Complex{Float64},2}},Nothing,var"#H#22"{Float64,Int64,Float64,Array{Any,1},Array{Any,1},Float64,Float64,Float64,SpinBasis{1//2,Int64}},Operator{SpinBasis{1//2,Int64},SpinBasis{1//2,Int64},Array{Complex{Float64},2}}},Operator{SpinBasis{1//2,Int64},SpinBasis{1//2,Int64},Array{Complex{Float64},2}},Operator{SpinBasis{1//2,Int64},SpinBasis{1//2,Int64},Array{Complex{Float64},2}}},LinearAlgebra.UniformScaling{Bool},Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing},Base.Iterators.Pairs{Union{},Union{},Tuple{},NamedTuple{(),Tuple{}}},DiffEqBase.StandardODEProblem},OrdinaryDiffEq.DP5,OrdinaryDiffEq.InterpolationData{DiffEqBase.ODEFunction{true,QuantumOptics.timeevolution.var"#df_#3"{QuantumOptics.timeevolution.var"#dmaster_#18"{Operator{SpinBasis{1//2,Int64},SpinBasis{1//2,Int64},Array{Complex{Float64},2}},Nothing,var"#H#22"{Float64,Int64,Float64,Array{Any,1},Array{Any,1},Float64,Float64,Float64,SpinBasis{1//2,Int64}},Operator{SpinBasis{1//2,Int64},SpinBasis{1//2,Int64},Array{Complex{Float64},2}}},Operator{SpinBasis{1//2,Int64},SpinBasis{1//2,Int64},Array{Complex{Float64},2}},Operator{SpinBasis{1//2,Int64},SpinBasis{1//2,Int64},Array{Complex{Float64},2}}},LinearAlgebra.UniformScaling{Bool},Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing},Array{Array{Complex{Float64},2},1},Array{Float64,1},Array{Array{Array{Complex{Float64},2},1},1},OrdinaryDiffEq.DP5Cache{Array{Complex{Float64},2},Array{Complex{Float64},2},Array{Complex{Float64},2},OrdinaryDiffEq.DP5ConstantCache{Float64,Float64}}},DiffEqBase.DEStats},DiffEqBase.ODEFunction{true,QuantumOptics.timeevolution.var"#df_#3"{QuantumOptics.timeevolution.var"#dmaster_#18"{Operator{SpinBasis{1//2,Int64},SpinBasis{1//2,Int64},Array{Complex{Float64},2}},Nothing,var"#H#22"{Float64,Int64,Float64,Array{Any,1},Array{Any,1},Float64,Float64,Float64,SpinBasis{1//2,Int64}},Operator{SpinBasis{1//2,Int64},SpinBasis{1//2,Int64},Array{Complex{Float64},2}}},Operator{SpinBasis{1//2,Int64},SpinBasis{1//2,Int64},Array{Complex{Float64},2}},Operator{SpinBasis{1//2,Int64},SpinBasis{1//2,Int64},Array{Complex{Float64},2}}},LinearAlgebra.UniformScaling{Bool},Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing},OrdinaryDiffEq.DP5Cache{Array{Complex{Float64},2},Array{Complex{Float64},2},Array{Complex{Float64},2},OrdinaryDiffEq.DP5ConstantCache{Float64,Float64}},OrdinaryDiffEq.DEOptions{Float64,Float64,Float64,Float64,typeof(DiffEqBase.ODE_DEFAULT_NORM),typeof(LinearAlgebra.opnorm),DiffEqBase.CallbackSet{Tuple{},Tuple{DiffEqBase.DiscreteCallback{DiffEqCallbacks.var"#30#31",DiffEqCallbacks.SavingAffect{QuantumOptics.timeevolution.var"#fout_#4"{Operator{SpinBasis{1//2,Int64},SpinBasis{1//2,Int64},Array{Complex{Float64},2}},QuantumOptics.timeevolution.var"#fout#7"{Operator{SpinBasis{1//2,Int64},SpinBasis{1//2,Int64},Array{Complex{Float64},2}}}},Float64,Operator{SpinBasis{1//2,Int64},SpinBasis{1//2,Int64},Array{Complex{Float64},2}},DataStructures.BinaryHeap{Float64,Base.Order.ForwardOrdering},Array{Float64,1}},typeof(DiffEqCallbacks.saving_initialize)}}},typeof(DiffEqBase.ODE_DEFAULT_ISOUTOFDOMAIN),typeof(DiffEqBase.ODE_DEFAULT_PROG_MESSAGE),typeof(DiffEqBase.ODE_DEFAULT_UNSTABLE_CHECK),DataStructures.BinaryHeap{Float64,Base.Order.ForwardOrdering},DataStructures.BinaryHea ...
#  [26] perform_step! at /home/ampolloreno/.julia/packages/OrdinaryDiffEq/HO8vN/src/perform_step/low_order_rk_perform_step.jl:775 [inlined]
#  [27] solve!(::OrdinaryDiffEq.ODEIntegrator{OrdinaryDiffEq.DP5,true,Array{Complex{Float64},2},Nothing,Float64,DiffEqBase.NullParameters,Float64,Float64,Float64,Array{Array{Complex{Float64},2},1},DiffEqBase.ODESolution{Complex{Float64},3,Array{Array{Complex{Float64},2},1},Nothing,Nothing,Array{Float64,1},Array{Array{Array{Complex{Float64},2},1},1},DiffEqBase.ODEProblem{Array{Complex{Float64},2},Tuple{Float64,Float64},true,DiffEqBase.NullParameters,DiffEqBase.ODEFunction{true,QuantumOptics.timeevolution.var"#df_#3"{QuantumOptics.timeevolution.var"#dmaster_#18"{Operator{SpinBasis{1//2,Int64},SpinBasis{1//2,Int64},Array{Complex{Float64},2}},Nothing,var"#H#22"{Float64,Int64,Float64,Array{Any,1},Array{Any,1},Float64,Float64,Float64,SpinBasis{1//2,Int64}},Operator{SpinBasis{1//2,Int64},SpinBasis{1//2,Int64},Array{Complex{Float64},2}}},Operator{SpinBasis{1//2,Int64},SpinBasis{1//2,Int64},Array{Complex{Float64},2}},Operator{SpinBasis{1//2,Int64},SpinBasis{1//2,Int64},Array{Complex{Float64},2}}},LinearAlgebra.UniformScaling{Bool},Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing},Base.Iterators.Pairs{Union{},Union{},Tuple{},NamedTuple{(),Tuple{}}},DiffEqBase.StandardODEProblem},OrdinaryDiffEq.DP5,OrdinaryDiffEq.InterpolationData{DiffEqBase.ODEFunction{true,QuantumOptics.timeevolution.var"#df_#3"{QuantumOptics.timeevolution.var"#dmaster_#18"{Operator{SpinBasis{1//2,Int64},SpinBasis{1//2,Int64},Array{Complex{Float64},2}},Nothing,var"#H#22"{Float64,Int64,Float64,Array{Any,1},Array{Any,1},Float64,Float64,Float64,SpinBasis{1//2,Int64}},Operator{SpinBasis{1//2,Int64},SpinBasis{1//2,Int64},Array{Complex{Float64},2}}},Operator{SpinBasis{1//2,Int64},SpinBasis{1//2,Int64},Array{Complex{Float64},2}},Operator{SpinBasis{1//2,Int64},SpinBasis{1//2,Int64},Array{Complex{Float64},2}}},LinearAlgebra.UniformScaling{Bool},Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing},Array{Array{Complex{Float64},2},1},Array{Float64,1},Array{Array{Array{Complex{Float64},2},1},1},OrdinaryDiffEq.DP5Cache{Array{Complex{Float64},2},Array{Complex{Float64},2},Array{Complex{Float64},2},OrdinaryDiffEq.DP5ConstantCache{Float64,Float64}}},DiffEqBase.DEStats},DiffEqBase.ODEFunction{true,QuantumOptics.timeevolution.var"#df_#3"{QuantumOptics.timeevolution.var"#dmaster_#18"{Operator{SpinBasis{1//2,Int64},SpinBasis{1//2,Int64},Array{Complex{Float64},2}},Nothing,var"#H#22"{Float64,Int64,Float64,Array{Any,1},Array{Any,1},Float64,Float64,Float64,SpinBasis{1//2,Int64}},Operator{SpinBasis{1//2,Int64},SpinBasis{1//2,Int64},Array{Complex{Float64},2}}},Operator{SpinBasis{1//2,Int64},SpinBasis{1//2,Int64},Array{Complex{Float64},2}},Operator{SpinBasis{1//2,Int64},SpinBasis{1//2,Int64},Array{Complex{Float64},2}}},LinearAlgebra.UniformScaling{Bool},Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing},OrdinaryDiffEq.DP5Cache{Array{Complex{Float64},2},Array{Complex{Float64},2},Array{Complex{Float64},2},OrdinaryDiffEq.DP5ConstantCache{Float64,Float64}},OrdinaryDiffEq.DEOptions{Float64,Float64,Float64,Float64,typeof(DiffEqBase.ODE_DEFAULT_NORM),typeof(LinearAlgebra.opnorm),DiffEqBase.CallbackSet{Tuple{},Tuple{DiffEqBase.DiscreteCallback{DiffEqCallbacks.var"#30#31",DiffEqCallbacks.SavingAffect{QuantumOptics.timeevolution.var"#fout_#4"{Operator{SpinBasis{1//2,Int64},SpinBasis{1//2,Int64},Array{Complex{Float64},2}},QuantumOptics.timeevolution.var"#fout#7"{Operator{SpinBasis{1//2,Int64},SpinBasis{1//2,Int64},Array{Complex{Float64},2}}}},Float64,Operator{SpinBasis{1//2,Int64},SpinBasis{1//2,Int64},Array{Complex{Float64},2}},DataStructures.BinaryHeap{Float64,Base.Order.ForwardOrdering},Array{Float64,1}},typeof(DiffEqCallbacks.saving_initialize)}}},typeof(DiffEqBase.ODE_DEFAULT_ISOUTOFDOMAIN),typeof(DiffEqBase.ODE_DEFAULT_PROG_MESSAGE),typeof(DiffEqBase.ODE_DEFAULT_UNSTABLE_CHECK),DataStructures.BinaryHeap{Float64,Base.Order.ForwardOrdering},DataStructures.BinaryHeap{Float ...
#  [28] #__solve#391 at /home/ampolloreno/.julia/packages/OrdinaryDiffEq/HO8vN/src/solve.jl:5 [inlined]
#  [29] #solve_call#456 at /home/ampolloreno/.julia/packages/DiffEqBase/gLFRA/src/solve.jl:65 [inlined]
#  [30] solve_up(::DiffEqBase.ODEProblem{Array{Complex{Float64},2},Tuple{Float64,Float64},true,DiffEqBase.NullParameters,DiffEqBase.ODEFunction{true,QuantumOptics.timeevolution.var"#df_#3"{QuantumOptics.timeevolution.var"#dmaster_#18"{Operator{SpinBasis{1//2,Int64},SpinBasis{1//2,Int64},Array{Complex{Float64},2}},Nothing,var"#H#22"{Float64,Int64,Float64,Array{Any,1},Array{Any,1},Float64,Float64,Float64,SpinBasis{1//2,Int64}},Operator{SpinBasis{1//2,Int64},SpinBasis{1//2,Int64},Array{Complex{Float64},2}}},Operator{SpinBasis{1//2,Int64},SpinBasis{1//2,Int64},Array{Complex{Float64},2}},Operator{SpinBasis{1//2,Int64},SpinBasis{1//2,Int64},Array{Complex{Float64},2}}},LinearAlgebra.UniformScaling{Bool},Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing},Base.Iterators.Pairs{Union{},Union{},Tuple{},NamedTuple{(),Tuple{}}},DiffEqBase.StandardODEProblem}, ::Nothing, ::Array{Complex{Float64},2}, ::DiffEqBase.NullParameters, ::OrdinaryDiffEq.DP5; kwargs::Base.Iterators.Pairs{Symbol,Any,NTuple{6,Symbol},NamedTuple{(:reltol, :abstol, :save_everystep, :save_start, :save_end, :callback),Tuple{Float64,Float64,Bool,Bool,Bool,DiffEqBase.CallbackSet{Tuple{},Tuple{DiffEqBase.DiscreteCallback{DiffEqCallbacks.var"#30#31",DiffEqCallbacks.SavingAffect{QuantumOptics.timeevolution.var"#fout_#4"{Operator{SpinBasis{1//2,Int64},SpinBasis{1//2,Int64},Array{Complex{Float64},2}},QuantumOptics.timeevolution.var"#fout#7"{Operator{SpinBasis{1//2,Int64},SpinBasis{1//2,Int64},Array{Complex{Float64},2}}}},Float64,Operator{SpinBasis{1//2,Int64},SpinBasis{1//2,Int64},Array{Complex{Float64},2}},DataStructures.BinaryHeap{Float64,Base.Order.ForwardOrdering},Array{Float64,1}},typeof(DiffEqCallbacks.saving_initialize)}}}}}}) at /home/ampolloreno/.julia/packages/DiffEqBase/gLFRA/src/solve.jl:86
#  [31] #solve#457 at /home/ampolloreno/.julia/packages/DiffEqBase/gLFRA/src/solve.jl:74 [inlined]
#  [32] integrate(::Array{Float64,1}, ::QuantumOptics.timeevolution.var"#dmaster_#18"{Operator{SpinBasis{1//2,Int64},SpinBasis{1//2,Int64},Array{Complex{Float64},2}},Nothing,var"#H#22"{Float64,Int64,Float64,Array{Any,1},Array{Any,1},Float64,Float64,Float64,SpinBasis{1//2,Int64}},Operator{SpinBasis{1//2,Int64},SpinBasis{1//2,Int64},Array{Complex{Float64},2}}}, ::Array{Complex{Float64},2}, ::Operator{SpinBasis{1//2,Int64},SpinBasis{1//2,Int64},Array{Complex{Float64},2}}, ::Operator{SpinBasis{1//2,Int64},SpinBasis{1//2,Int64},Array{Complex{Float64},2}}, ::QuantumOptics.timeevolution.var"#fout#7"{Operator{SpinBasis{1//2,Int64},SpinBasis{1//2,Int64},Array{Complex{Float64},2}}}; alg::OrdinaryDiffEq.DP5, steady_state::Bool, tol::Float64, save_everystep::Bool, saveat::Array{Float64,1}, callback::Nothing, kwargs::Base.Iterators.Pairs{Union{},Union{},Tuple{},NamedTuple{(),Tuple{}}}) at /home/ampolloreno/.julia/packages/QuantumOptics/MmggF/src/timeevolution_base.jl:57
#  [33] integrate at /home/ampolloreno/.julia/packages/QuantumOptics/MmggF/src/timeevolution_base.jl:20 [inlined]
#  [34] #integrate#6 at /home/ampolloreno/.julia/packages/QuantumOptics/MmggF/src/timeevolution_base.jl:73 [inlined]
#  [35] integrate at /home/ampolloreno/.julia/packages/QuantumOptics/MmggF/src/timeevolution_base.jl:70 [inlined]
#  [36] #integrate_master#24 at /home/ampolloreno/.julia/packages/QuantumOptics/MmggF/src/master.jl:185 [inlined]
#  [37] integrate_master at /home/ampolloreno/.julia/packages/QuantumOptics/MmggF/src/master.jl:181 [inlined]
#  [38] #master_dynamic#17 at /home/ampolloreno/.julia/packages/QuantumOptics/MmggF/src/master.jl:161 [inlined]
#  [39] master_dynamic at /home/ampolloreno/.julia/packages/QuantumOptics/MmggF/src/master.jl:159 [inlined]
#  [40] macro expansion at /home/ampolloreno/.julia/packages/QuantumOptics/MmggF/src/timeevolution_base.jl:100 [inlined]
#  [41] (::var"#evaluator#21"{Ket{SpinBasis{1//2,Int64},Array{Complex{Float64},1}},Array{Float64,1},Array{Any,1},Array{Any,1},Float64,Float64,Float64,SpinBasis{1//2,Int64},StepRange{Int64,Int64}})(::Float64, ::Int64) at ./In[25]:10
#  [42] top-level scope at ./In[68]:9
#  [43] include_string(::Function, ::Module, ::String, ::String) at ./loading.jl:1091

# %%
using Plots
max_ρ = 1
min_ρ = .0
ρs = range(min_ρ, max_ρ, step=max_ρ/10)
angle = π/2
target2 = [Real.(expect(sigmax(b), gaussian_spin_profile(ρ, angle))) for ρ in ρs]
y2s = [Real.(expect(sigmax(b), sequential_exact_evolution(ρ, angle))) for ρ in ρs];
plot(ρs, [target2, y2s])
# Out:
# 
