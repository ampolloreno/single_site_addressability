# %%
using Cubature

# %%
function R(n::Int64, m::Int64, ρ::Float64)
    if (n - m) % 2 != 0
        0
    else
        function summand(k)
            n = big(n)
            k = big(k)
            (-1)^k * factorial(n-k)/(factorial(k)*factorial(Int((n+m)/2) - k)*factorial(Int((n-m)/2) - k))*(ρ)^(n-2*k)
        end
        mapreduce(summand, +, Array(range(0, stop=Int((n-m)/2), step=1)))
    end
end

function Z(n, m, ρ, θ)
    if m < 0
        R(n, abs(m), ρ) * sin(abs(m) * θ)
    else
        R(n, m, ρ) * cos(m * θ)
    end
end
# Out:
# Z (generic function with 1 method)

# %%
σ1 = .3
σ2 = .3
displacement = 0.
function integrand(n, m)
    function rtn(coor)
        ρ = coor[1]
        θ = coor[2]
        x = ρ * cos(θ) + displacement
        y = ρ * sin(θ)
        Z(n, m, ρ, θ) * exp(-x^2/σ1^2 - y^2/σ2^2) * ρ
    end
    rtn
end
# Out:
# integrand (generic function with 1 method)

# %%
function neumann(m)
    if m == 0
        2
    else 
        1
    end
end
function cond_eval(n, m)
    if -n ≤ m ≤ n
        (2*n+2)/(π*neumann(m)) * hcubature(integrand(n, m), [0., 0.], [1., 2*π], maxevals=1000)[1]
    else
        0
    end
end
# Out:
# cond_eval (generic function with 1 method)

# %%
using Plots
gr()
maxm = 10

heatmap(hcat([[c[1]^2 for c in [cond_eval(n, m) for n in range(0, 4*maxm, step=1)]] for m in range(0, maxm, step=1)]...))

# %%
heatmap(hcat([[c[1]^2 for c in [cond_eval(n, m) for n in range(0, 4*maxn, step=1)]] for m in range(-maxn, 0, step=1)]...))

# %%
coeffs1[1] = 0
# Out:
# 0

# %%
using Plots
plot((coeffs1 + reverse(coeffs2))[1:end])
